# %%
import create_signals
from matplotlib import pyplot as plt

# %%
freqs = [27, 40, 55, 59, 76]
Fs = 200
N = 5
[approx, y, adj] = create_signals.create_signals_AR(N, 15, 50, 100, 1000, Fs, freqs, .05) # 5 nodes, 10 time lags, 100 samples of inovation, 500 samples total

# %%
print(approx.shape)
print(approx[0,:,:])
plt.plot(approx[1,:,:])
# Out:
# (20, 16, 5)
# [[ 1.00000000e+00  1.00000000e+00  1.00000000e+00  1.00000000e+00
#    1.00000000e+00]
#  [-3.33158028e-01 -4.69659407e-01 -2.25172151e-01  9.01517518e-02
#    6.81662241e-01]
#  [ 5.04925667e-01  8.86668647e-01  5.61986981e-01  3.42693342e-01
#    5.13070680e-01]
#  [ 2.71932405e-02 -1.00361124e-01  4.97592110e-02 -4.34966697e-02
#   -7.27071210e-02]
#  [ 3.00236790e-01  1.02540937e-01  8.40084446e-02  4.25573409e-01
#    3.95130877e-01]
#  [ 3.42547179e-01  1.31399242e-01  2.89846734e-01  2.35315319e-01
#    3.28809823e-01]
#  [ 5.52476514e-02  1.49311712e-02  3.22300671e-02  1.20246327e-01
#    4.56680482e-01]
#  [-2.94443936e-01 -8.41332337e-02 -1.05992068e-01 -2.47275884e-01
#    3.85997818e-02]
#  [ 1.07918024e-01  3.63039432e-01  1.24377026e-01  4.53893329e-02
#   -9.05780660e-02]
#  [ 1.47594476e-01 -1.91408157e-01  8.84523113e-02  3.14060327e-01
#    2.11269409e-01]
#  [-5.97809321e-02  5.37690912e-02 -1.03372366e-01 -4.13587851e-02
#    2.00405273e-01]
#  [ 1.09011390e-01 -3.41725630e-04  2.37386236e-01  2.72647322e-02
#    1.49015693e-01]
#  [-2.94272792e-02  1.16932076e-01  4.13905574e-02  1.01555246e-01
#    1.82232086e-01]
#  [ 2.89105368e-02  7.28628090e-02  1.19830826e-01  3.85279960e-02
#    8.51798157e-02]
#  [ 3.68115672e-02 -9.54400023e-03 -1.06187752e-01  1.34973666e-02
#   -6.73028452e-02]
#  [ 4.84061185e-03  7.59749884e-02 -6.94306987e-02 -1.52602821e-01
#   -8.62732587e-02]]
# [<matplotlib.lines.Line2D at 0x7f49c922b640>,
#  <matplotlib.lines.Line2D at 0x7f49c922b6a0>,
#  <matplotlib.lines.Line2D at 0x7f49c922b6d0>,
#  <matplotlib.lines.Line2D at 0x7f49c922b7c0>,
#  <matplotlib.lines.Line2D at 0x7f49c922b8b0>]

# %%
plt.plot(y)
plt.figure()
plt.plot(approx.T)
plt.figure()
plt.plot(err)
# Out:
# [<matplotlib.lines.Line2D at 0x7ff884e3b190>,
#  <matplotlib.lines.Line2D at 0x7ff884e3b250>,
#  <matplotlib.lines.Line2D at 0x7ff884e3b010>,
#  <matplotlib.lines.Line2D at 0x7ff884e39870>,
#  <matplotlib.lines.Line2D at 0x7ff884e39690>]
